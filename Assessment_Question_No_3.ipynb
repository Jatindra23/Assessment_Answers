# %%
# !pip install pandas pydub openpyxl tqdm

# =======================
#  Import Libraries
# =======================
import os
from pydub import AudioSegment
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
from tqdm import tqdm


# Mount working directory
BASE_DIR = "/content/drive/MyDrive/disfluency_project"
os.makedirs(BASE_DIR, exist_ok=True)

# %%
csv_path = "/content/drive/MyDrive/whisper_train_manifest_fullpath.csv"
list_path = "/content/drive/MyDrive/Speech Disfluencies List.xlsx"
result_path = "/content/drive/MyDrive/Speech Disfluencies Result.xlsx"
output_audio_dir = "/content/disfluency_segments"                  # Folder for saving short clips

os.makedirs(output_audio_dir, exist_ok=True)

df_main = pd.read_csv(csv_path)
df_list = pd.read_excel(list_path)
df_result = pd.read_excel(result_path)

print(" Files Loaded Successfully!")
print("Main Dataset Columns:", df_main.columns.tolist())
print("List Columns:", df_list.columns.tolist())
print("Result Columns:", df_result.columns.tolist())
# Out:
# ✅ Files Loaded Successfully!
# Main Dataset Columns: ['audio', 'transcript']
# List Columns: ['Filled Pause', 'Repetition', 'False Start', 'Prolongation', 'Self-Correction']
# Result Columns: ['disfluency_type', 'audio_segment_url', 'start_time (s)', 'end_time (s)', 'transcription_snippet', 'notes']

# %%
df_main
# Out:
#                                                   audio  \
# 0     /content/drive/MyDrive/whisper_audio/split_aud...
# 1     /content/drive/MyDrive/whisper_audio/split_aud...
# 2     /content/drive/MyDrive/whisper_audio/split_aud...
# 3     /content/drive/MyDrive/whisper_audio/split_aud...
# 4     /content/drive/MyDrive/whisper_audio/split_aud...
# ...                                                 ...
# 2495  /content/drive/MyDrive/whisper_audio/split_aud...
# 2496  /content/drive/MyDrive/whisper_audio/split_aud...
# 2497  /content/drive/MyDrive/whisper_audio/split_aud...
# 2498  /content/drive/MyDrive/whisper_audio/split_aud...
# 2499  /content/drive/MyDrive/whisper_audio/split_aud...
#
#                                              transcript
# 0     [\n  {\n    "start": 0.11,\n    "end": 14.42,\...
# 1     अनुभव करके कुछ लिखना था तो वह तो बिना देखिए नह...
# 2     नीचे"\n  },\n  {\n    "start": 42.47,\n    "en...
# 3     तो जब पता जैसी रात हुआ ना शाम मतलब छै सात में ...
# 4     ता सब अपना अपना कैम्प डाल के रह रहा था और हम अ...
# ...                                                 ...
# 2495  ें कही पे भी नहीं है तो अगर हम दो हजार पैतालीस...
# 2496  ": "जी जी"\n  },\n  {\n    "start": 993.07,\n ...
# 2497  से बड़ा तो हाथ उनका जो आपके इलाके का डीएम होता...
# 2498  हजार पैंतालीस तक अगर इसमें बदलाव नहीं आएगा लोग...
# 2499  र इकट्ठा करके अपनी फैम मतलब ज्यादा बहुत ज्यादा...
#
# [2500 rows x 2 columns]

# %%
#  Prepare Disfluency Terms
# =======================
disfluency_terms = []

for col in df_list.columns:
    # drop NaN, strip spaces
    words = df_list[col].dropna().astype(str).str.strip().tolist()
    disfluency_terms.extend(words)

# Remove duplicates
disfluency_terms = list(set(disfluency_terms))

print(f" Total Disfluency Terms Loaded: {len(disfluency_terms)}")
print(disfluency_terms[:10])
# Out:
# ✅ Total Disfluency Terms Loaded: 193
# ['एक्चुअली बनाते हुए मतलब मान के चलिए', 'हम्म्म', 'ह ह ह', 'जी-हाँ-हाँ-जी-हाँ', 'कुछ ना कुछ तो मेरे तो', 'बस बस', 'आ रही आ रही आ रही', 'आह—नहीं—', 'आप अ', 'अच्छ्छ्छा']

# %%
# =======================
#  Search Disfluencies in Transcripts
# =======================
results = []

for idx, row in tqdm(df_main.iterrows(), total=len(df_main)):
    audio_path = row['audio']
    transcript = str(row['transcript']).strip()

    # Find which disfluency terms appear
    matched_terms = [term for term in disfluency_terms if term in transcript]

    if matched_terms:
        # store all matches for this segment
        for term in matched_terms:
            results.append({
                "recording_id": os.path.basename(audio_path),
                "disfluency": term,
                "audio_path": audio_path,
                "transcript": transcript
            })
# Out:
# 100%|██████████| 2500/2500 [00:00<00:00, 5492.05it/s]

# %%
# =======================
# Create DataFrame of Results
# =======================
df_out = pd.DataFrame(results)
print(f"Found Disfluency Segments: {len(df_out)}")

if len(df_out) > 0:
    # Save structured dataset
    output_csv = "/content/drive/MyDrive/Detected_Disfluencies.csv"
    df_out.to_csv(output_csv, index=False)
    print(f" Structured dataset saved at: {output_csv}")
else:
    print(" No disfluencies found. Check if words match exactly with transcripts.")
# Out:
# Found Disfluency Segments: 2583
#  Structured dataset saved at: /content/drive/MyDrive/Detected_Disfluencies.csv

# %%
df_out
# Out:
#                 recording_id disfluency  \
# 0      825780_audio_seg0.wav       अच्छ
# 1      825780_audio_seg0.wav      वो तो
# 2      825780_audio_seg6.wav        हम्
# 3      825780_audio_seg6.wav       हम्म
# 4      825780_audio_seg7.wav         अं
# ...                      ...        ...
# 2578  840781_audio_seg34.wav       अच्छ
# 2579  840781_audio_seg34.wav         अं
# 2580  840781_audio_seg35.wav        बिल
# 2581  840781_audio_seg36.wav       अच्छ
# 2582  840781_audio_seg36.wav         ज़
#
#                                              audio_path  \
# 0     /content/drive/MyDrive/whisper_audio/split_aud...
# 1     /content/drive/MyDrive/whisper_audio/split_aud...
# 2     /content/drive/MyDrive/whisper_audio/split_aud...
# 3     /content/drive/MyDrive/whisper_audio/split_aud...
# 4     /content/drive/MyDrive/whisper_audio/split_aud...
# ...                                                 ...
# 2578  /content/drive/MyDrive/whisper_audio/split_aud...
# 2579  /content/drive/MyDrive/whisper_audio/split_aud...
# 2580  /content/drive/MyDrive/whisper_audio/split_aud...
# 2581  /content/drive/MyDrive/whisper_audio/split_aud...
# 2582  /content/drive/MyDrive/whisper_audio/split_aud...
#
#                                              transcript
# 0     [\n  {\n    "start": 0.11,\n    "end": 14.42,\...
# 1     [\n  {\n    "start": 0.11,\n    "end": 14.42,\...
# 2     "speaker_id": 245746,\n    "text": "हम्म हम लो...
# 3     "speaker_id": 245746,\n    "text": "हम्म हम लो...
# 4     थे तो मेको समझ में आ नहीं रहा था कि क्या बोल र...
# ...                                                 ...
# 2578  से बड़ा तो हाथ उनका जो आपके इलाके का डीएम होता...
# 2579  से बड़ा तो हाथ उनका जो आपके इलाके का डीएम होता...
# 2580  हजार पैंतालीस तक अगर इसमें बदलाव नहीं आएगा लोग...
# 2581  र इकट्ठा करके अपनी फैम मतलब ज्यादा बहुत ज्यादा...
# 2582  र इकट्ठा करके अपनी फैम मतलब ज्यादा बहुत ज्यादा...
#
# [2583 rows x 4 columns]

# %%
# =======================
# Step 8: Clip Audio Segments
# =======================
# Since timestamps aren't provided, we export entire segment audio
# Each row = one utterance containing at least one disfluency

segmented_paths = []

for i, row in tqdm(df_out.iterrows(), total=len(df_out)):
    audio_path = row['audio_path']
    dis_term = row['disfluency']

    if os.path.exists(audio_path):
        try:
            audio = AudioSegment.from_file(audio_path)
            out_path = os.path.join(output_audio_dir, f"{i}_{dis_term}.wav")
            audio.export(out_path, format="wav")
            segmented_paths.append(out_path)
        except Exception as e:
            print(f"⚠️ Error processing {audio_path}: {e}")
            segmented_paths.append("ERROR")
    else:
        segmented_paths.append("NOT_FOUND")

df_out["segmented_audio_path"] = segmented_paths

# Save final dataset with segmented clip paths
final_csv = "/content/Final_Disfluency_Segments.csv"
df_out.to_csv(final_csv, index=False)

print(f" Final Dataset saved at: {final_csv}")
print(f" Segmented clips stored in: {output_audio_dir}")
# Out:
# 100%|██████████| 2583/2583 [14:08<00:00,  3.04it/s]
# ✅ Final Dataset saved at: /content/Final_Disfluency_Segments.csv
# 🎧 Segmented clips stored in: /content/disfluency_segments

# %%
pd.read_csv(final_csv).head(50)
# Out:
#               recording_id       disfluency  \
# 0    825780_audio_seg0.wav             अच्छ
# 1    825780_audio_seg0.wav            वो तो
# 2    825780_audio_seg6.wav              हम्
# 3    825780_audio_seg6.wav             हम्म
# 4    825780_audio_seg7.wav               अं
# 5    825727_audio_seg1.wav            हा हा
# 6    825727_audio_seg2.wav              बिल
# 7    825727_audio_seg3.wav               आह
# 8    825727_audio_seg3.wav            हा हा
# 9    825727_audio_seg4.wav             अच्छ
# 10   825727_audio_seg5.wav               अह
# 11   825727_audio_seg6.wav             अच्छ
# 12   825727_audio_seg6.wav               अह
# 13   825727_audio_seg7.wav               अह
# 14   825727_audio_seg7.wav           अह्ह्ह
# 15   825727_audio_seg7.wav               हह
# 16   825727_audio_seg7.wav              हूँ
# 17   825727_audio_seg8.wav            वो तो
# 18   825727_audio_seg9.wav            वो तो
# 19  825727_audio_seg11.wav               ज़
# 20  825727_audio_seg13.wav              बिल
# 21  825727_audio_seg13.wav            वो तो
# 22  825727_audio_seg13.wav  बिल्कुल बिल्कुल
# 23   988596_audio_seg1.wav             अच्छ
# 24   988596_audio_seg2.wav             अच्छ
# 25   988596_audio_seg3.wav               ज़
# 26  988596_audio_seg13.wav              बिल
# 27   990175_audio_seg1.wav             अच्छ
# 28   990175_audio_seg2.wav             अच्छ
# 29   990175_audio_seg2.wav               अह
# 30   990175_audio_seg3.wav               आह
# 31   990175_audio_seg3.wav             अच्छ
# 32   990175_audio_seg6.wav               अह
# 33   990175_audio_seg8.wav               अह
# 34  990175_audio_seg10.wav              ओके
# 35  990175_audio_seg10.wav              हूँ
# 36  990175_audio_seg11.wav              ओके
# 37   526266_audio_seg3.wav               आं
# 38   526266_audio_seg4.wav              उम्
# 39   526266_audio_seg4.wav             उम्म
# 40   526266_audio_seg5.wav               आह
# 41   526266_audio_seg7.wav             अच्छ
# 42   526266_audio_seg8.wav              उम्
# 43  526266_audio_seg11.wav               अं
# 44  526266_audio_seg12.wav               अं
# 45  526266_audio_seg13.wav              हूँ
# 46  526266_audio_seg14.wav               अह
# 47  526266_audio_seg15.wav              ओके
# 48   520199_audio_seg2.wav             अच्छ
# 49   520199_audio_seg2.wav              बिल
#
#                                            audio_path  \
# 0   /content/drive/MyDrive/whisper_audio/split_aud...
# 1   /content/drive/MyDrive/whisper_audio/split_aud...
# 2   /content/drive/MyDrive/whisper_audio/split_aud...
# 3   /content/drive/MyDrive/whisper_audio/split_aud...
# 4   /content/drive/MyDrive/whisper_audio/split_aud...
# 5   /content/drive/MyDrive/whisper_audio/split_aud...
# 6   /content/drive/MyDrive/whisper_audio/split_aud...
# 7   /content/drive/MyDrive/whisper_audio/split_aud...
# 8   /content/drive/MyDrive/whisper_audio/split_aud...
# 9   /content/drive/MyDrive/whisper_audio/split_aud...
# 10  /content/drive/MyDrive/whisper_audio/split_aud...
# 11  /content/drive/MyDrive/whisper_audio/split_aud...
# 12  /content/drive/MyDrive/whisper_audio/split_aud...
# 13  /content/drive/MyDrive/whisper_audio/split_aud...
# 14  /content/drive/MyDrive/whisper_audio/split_aud...
# 15  /content/drive/MyDrive/whisper_audio/split_aud...
# 16  /content/drive/MyDrive/whisper_audio/split_aud...
# 17  /content/drive/MyDrive/whisper_audio/split_aud...
# 18  /content/drive/MyDrive/whisper_audio/split_aud...
# 19  /content/drive/MyDrive/whisper_audio/split_aud...
# 20  /content/drive/MyDrive/whisper_audio/split_aud...
# 21  /content/drive/MyDrive/whisper_audio/split_aud...
# 22  /content/drive/MyDrive/whisper_audio/split_aud...
# 23  /content/drive/MyDrive/whisper_audio/split_aud...
# 24  /content/drive/MyDrive/whisper_audio/split_aud...
# 25  /content/drive/MyDrive/whisper_audio/split_aud...
# 26  /content/drive/MyDrive/whisper_audio/split_aud...
# 27  /content/drive/MyDrive/whisper_audio/split_aud...
# 28  /content/drive/MyDrive/whisper_audio/split_aud...
# 29  /content/drive/MyDrive/whisper_audio/split_aud...
# 30  /content/drive/MyDrive/whisper_audio/split_aud...
# 31  /content/drive/MyDrive/whisper_audio/split_aud...
# 32  /content/drive/MyDrive/whisper_audio/split_aud...
# 33  /content/drive/MyDrive/whisper_audio/split_aud...
# 34  /content/drive/MyDrive/whisper_audio/split_aud...
# 35  /content/drive/MyDrive/whisper_audio/split_aud...
# 36  /content/drive/MyDrive/whisper_audio/split_aud...
# 37  /content/drive/MyDrive/whisper_audio/split_aud...
# 38  /content/drive/MyDrive/whisper_audio/split_aud...
# 39  /content/drive/MyDrive/whisper_audio/split_aud...
# 40  /content/drive/MyDrive/whisper_audio/split_aud...
# 41  /content/drive/MyDrive/whisper_audio/split_aud...
# 42  /content/drive/MyDrive/whisper_audio/split_aud...
# 43  /content/drive/MyDrive/whisper_audio/split_aud...
# 44  /content/drive/MyDrive/whisper_audio/split_aud...
# 45  /content/drive/MyDrive/whisper_audio/split_aud...
# 46  /content/drive/MyDrive/whisper_audio/split_aud...
# 47  /content/drive/MyDrive/whisper_audio/split_aud...
# 48  /content/drive/MyDrive/whisper_audio/split_aud...
# 49  /content/drive/MyDrive/whisper_audio/split_aud...
#
#                                            transcript  \
# 0   [\n  {\n    "start": 0.11,\n    "end": 14.42,\...
# 1   [\n  {\n    "start": 0.11,\n    "end": 14.42,\...
# 2   "speaker_id": 245746,\n    "text": "हम्म हम लो...
# 3   "speaker_id": 245746,\n    "text": "हम्म हम लो...
# 4   थे तो मेको समझ में आ नहीं रहा था कि क्या बोल र...
# 5   },\n  {\n    "start": 34.37,\n    "end": 34.88...
# 6   ,\n    "speaker_id": 291038,\n    "text": "बिल...
# 7   id": 291038,\n    "text": "जी जी जी आह"\n  },\...
# 8   id": 291038,\n    "text": "जी जी जी आह"\n  },\...
# 9   "end": 140.36,\n    "speaker_id": 291038,\n   ...
# 10  है न"\n  },\n  {\n    "start": 166.28,\n    "e...
# 11  "end": 214.01,\n    "speaker_id": 291038,\n   ...
# 12  "end": 214.01,\n    "speaker_id": 291038,\n   ...
# 13  जंगल है लगभग मेरे को लगता है बारह किलोमीटर मे ...
# 14  जंगल है लगभग मेरे को लगता है बारह किलोमीटर मे ...
# 15  जंगल है लगभग मेरे को लगता है बारह किलोमीटर मे ...
# 16  जंगल है लगभग मेरे को लगता है बारह किलोमीटर मे ...
# 17  r_id": 291038,\n    "text": "ठीक हैं तो हम लोग...
# 18  हम लोग कैंपिंग किए थे जंगल में मिजोरम में जंगल...
# 19  : 327.53,\n    "speaker_id": 291038,\n    "tex...
# 20  के रात को मतलब उसके"\n  },\n  {\n    "start": ...
# 21  के रात को मतलब उसके"\n  },\n  {\n    "start": ...
# 22  के रात को मतलब उसके"\n  },\n  {\n    "start": ...
# 23  "जी जी"\n  },\n  {\n    "start": 100.76,\n    ...
# 24  ": "जी जी।"\n  },\n  {\n    "start": 134.12,\n...
# 25  text": "जी जी"\n  },\n  {\n    "start": 180.02...
# 26  नतीजा निकला तो कभी ऐसा कुछ शरारत किये है जिनका...
# 27  6,\n    "text": "जैसे मेरी मम्मी ने कभी कोई अच...
# 28  छी नहीं लगती थी तो फिर क्या करती थी या तो मैं ...
# 29  छी नहीं लगती थी तो फिर क्या करती थी या तो मैं ...
# 30  आए तो उनका मतलब उनको वह खराब लग रहा है लेकिन ज...
# 31  आए तो उनका मतलब उनको वह खराब लग रहा है लेकिन ज...
# 32  मम्मी ने चार पुरिया दी है तो मैं उसको दो पुरी ...
# 33  ाती थी"\n  },\n  {\n    "start": 142.37,\n    ...
# 34  लोग डैली उनको देखने जाते थे उनको खाना खिलाते ख...
# 35  लोग डैली उनको देखने जाते थे उनको खाना खिलाते ख...
# 36  : 204.29,\n    "end": 204.92,\n    "speaker_id...
# 37  "text": "कर लेते हैं तो फिर उनका जो बदन है ना ...
# 38  िए तो फिर उनके चाचा ने बोलते थे उसके खुब"\n  }...
# 39  िए तो फिर उनके चाचा ने बोलते थे उसके खुब"\n  }...
# 40  जल गया है क्या भी हुआ जो भी हो तो उनसे प्यार क...
# 41  "start": 196.66,\n    "end": 201.55,\n    "spe...
# 42  ी हां एक विवाह इसी में होता है कि उनके फैमिली ...
# 43  "start": 308.74,\n    "end": 315.76,\n    "spe...
# 44  ,\n    "text": "दुखद अंत और खुशाल अंत दुख और ख...
# 45  88.42,\n    "speaker_id": 286851,\n    "text":...
# 46  न दोनों का शादी भी हो गया कुछ गलत फेमी के वजह ...
# 47  शी खुशी शादी कर ली एक साथ रुके"\n  },\n  {\n  ...
# 48  : 494,\n    "text": "जी"\n  },\n  {\n    "star...
# 49  : 494,\n    "text": "जी"\n  },\n  {\n    "star...
#
#                                  segmented_audio_path
# 0             /content/disfluency_segments/0_अच्छ.wav
# 1            /content/disfluency_segments/1_वो तो.wav
# 2              /content/disfluency_segments/2_हम्.wav
# 3             /content/disfluency_segments/3_हम्म.wav
# 4               /content/disfluency_segments/4_अं.wav
# 5            /content/disfluency_segments/5_हा हा.wav
# 6              /content/disfluency_segments/6_बिल.wav
# 7               /content/disfluency_segments/7_आह.wav
# 8            /content/disfluency_segments/8_हा हा.wav
# 9             /content/disfluency_segments/9_अच्छ.wav
# 10             /content/disfluency_segments/10_अह.wav
# 11           /content/disfluency_segments/11_अच्छ.wav
# 12             /content/disfluency_segments/12_अह.wav
# 13             /content/disfluency_segments/13_अह.wav
# 14         /content/disfluency_segments/14_अह्ह्ह.wav
# 15             /content/disfluency_segments/15_हह.wav
# 16            /content/disfluency_segments/16_हूँ.wav
# 17          /content/disfluency_segments/17_वो तो.wav
# 18          /content/disfluency_segments/18_वो तो.wav
# 19             /content/disfluency_segments/19_ज़.wav
# 20            /content/disfluency_segments/20_बिल.wav
# 21          /content/disfluency_segments/21_वो तो.wav
# 22  /content/disfluency_segments/22_बिल्कुल बिल्कु...
# 23           /content/disfluency_segments/23_अच्छ.wav
# 24           /content/disfluency_segments/24_अच्छ.wav
# 25             /content/disfluency_segments/25_ज़.wav
# 26            /content/disfluency_segments/26_बिल.wav
# 27           /content/disfluency_segments/27_अच्छ.wav
# 28           /content/disfluency_segments/28_अच्छ.wav
# 29             /content/disfluency_segments/29_अह.wav
# 30             /content/disfluency_segments/30_आह.wav
# 31           /content/disfluency_segments/31_अच्छ.wav
# 32             /content/disfluency_segments/32_अह.wav
# 33             /content/disfluency_segments/33_अह.wav
# 34            /content/disfluency_segments/34_ओके.wav
# 35            /content/disfluency_segments/35_हूँ.wav
# 36            /content/disfluency_segments/36_ओके.wav
# 37             /content/disfluency_segments/37_आं.wav
# 38            /content/disfluency_segments/38_उम्.wav
# 39           /content/disfluency_segments/39_उम्म.wav
# 40             /content/disfluency_segments/40_आह.wav
# 41           /content/disfluency_segments/41_अच्छ.wav
# 42            /content/disfluency_segments/42_उम्.wav
# 43             /content/disfluency_segments/43_अं.wav
# 44             /content/disfluency_segments/44_अं.wav
# 45            /content/disfluency_segments/45_हूँ.wav
# 46             /content/disfluency_segments/46_अह.wav
# 47            /content/disfluency_segments/47_ओके.wav
# 48           /content/disfluency_segments/48_अच्छ.wav
# 49            /content/disfluency_segments/49_बिल.wav
